# %% [markdown]
# # How to use an Encoder-Decoder LSTM to Echo Sequences of Random Integers
# A powerful feature of Long Short-Term Memory (LSTM) recurrent neural networks is that they can remember observations over long sequence intervals.
#
# This can be demonstrated by contriving a simple sequence echo problem where the entire input sequence or partial contiguous blocks of the input sequence are echoed as an output sequence.
#
# Developing LSTM recurrent neural networks to address the sequence echo problem is both a good demonstration of the power of LSTMs and can be used to demonstrate state-of-the-art recurrent neural network architectures.
#
# In this post, you will discover how to develop LSTMs to solve the full and partial sequence echo problem in Python using the Keras deep learning library.
#
# After completing this tutorial, you will know:
#
# * How to generate random sequences of integers, represent them using a one hot encoding and frame the sequence as a supervised learning problem with input and output pairs.
# * How to develop a sequence-to-sequence LSTM to echo the entire input sequence as an output.
# * How to develop an encoder-decoder LSTM to echo partial sequences with lengths that differ from the input sequence.
#
# Let’s get started.

# %% [markdown]
# ## Overview
# This tutorial is divided into 3 parts; they are:
#
# 1. Sequence Echo Problem
# 2. Echo Whole Sequence (sequence-to-sequence model)
# 3. Echo Partial Sequence (encoder-decoder model)
#
# ## Sequence Echo Problem
# The echo sequence problem involves exposing an LSTM to a sequence of observations, one at a time, then asking the network to echo back a partial or full list of contiguous observations observed.
#
# This forces the network to remember blocks of contiguous observations and is a great demonstration of the learning power of LSTM recurrent neural networks.
#
# The first step is to write some code to generate a random sequence of integers and encode them for the network.
#
# This involves 3 steps:
#
# 1. Generate Random Sequence
# 2. One Hot Encode Random Sequence
# 3. Frame Encoded Sequences for Learning
#
# ### Generate Random Sequence
# We can generate random integers in Python using the [randint()](https://docs.python.org/3/library/random.html#random.randint) function that takes two parameters, indicating the range of integers from which to draw values.
#
# In this tutorial, we will define the problem as having integer values between 0 and 99 with 100 unique values.

# %%
	
randint(0, 99)

# %% [markdown]
# We can put this in a function called generate_sequence() that will generate a sequence of random integers of the desired length, with the default length set to 25 elements.
#
# This function is listed below.

# %%
# generate a sequence of random numbers in [0, 99]
def generate_sequence(length=25):
	return [randint(0, 99) for _ in range(length)]

# %% [markdown]
# ### One Hot Encode Random Sequence
# Once we have generated sequences of random integers, we need to transform them into a format that is suitable for training an LSTM network.
#
# One option would be to rescale the integer to the range [0,1]. This would work and would require that the problem be phrased as regression.
#
# I am interested in predicting the right number, not a number close to the expected value. This means I would prefer to frame the problem as classification rather than regression, where the expected output is a class and there are 100 possible class values.
#
# In this case, we can use a one hot encoding of the integer values where each value is represented by a 100 elements binary vector that is all “0” values except the index of the integer, which is marked 1.
#
# The function below called one_hot_encode() defines how to iterate over a sequence of integers and create a binary vector representation for each and returns the result as a 2-dimensional array.

# %%
# one hot encode sequence
def one_hot_encode(sequence, n_unique=100):
	encoding = list()
	for value in sequence:
		vector = [0 for _ in range(n_unique)]
		vector[value] = 1
		encoding.append(vector)
	return array(encoding)

# %% [markdown]
# We also need to decode the encoded values so that we can make use of the predictions, in this case, just review them.
#
# The one hot encoding can be inverted by using the [argmax() NumPy](https://docs.scipy.org/doc/numpy/reference/generated/numpy.argmax.html) function that returns the index of the value in the vector with the largest value.
#
# The function below, named one_hot_decode(), will decode an encoded sequence and can be used to later decode predictions from our network.

# %%
# decode a one hot encoded string
def one_hot_decode(encoded_seq):
	return [argmax(vector) for vector in encoded_seq]

# %% [markdown]
# ### Frame Encoded Sequences for Learning
# Once the sequences have been generated and encoded, they must be organized into a framing suitable for learning.
#
# This involves organizing the linear sequence into input (X) and output (y) pairs.
#
# For example, the sequence [1, 2, 3, 4, 5] can be framed as a sequence prediction problem with 2 inputs (t and t-1) and 1 output (t-1) as follows:

# %%
X,			y
NaN, 1,		NaN
1, 2,		1
2, 3,		2
3, 4,		3
4, 5,		4
5, NaN,		5

# %% [markdown]
# Note that the absence of data is marked with a NaN value. These rows can be padded with special characters and masked. Alternatively, and more simply, these rows can be removed from the dataset, at the cost of providing fewer examples from a sequence from which to learn. This latter approach will be the approach used in this example.
#
# We will use the [Pandas shift() function](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shift.html) to create shifted versions of the encoded sequence. The rows with missing data are removed with the [dropna() function](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dropna.html).
#
# We can then specify the input and output data from the shifted data frame. The data must be 3-dimensional for use with sequence prediction LSTMs. Both input and output require the dimensions [samples, timesteps, features], where samples is the number of rows, timesteps is the number of lag observations from which to learn to make predictions, and features is the number of separate values (e.g. 100 for the one hot encoding).
#
# The code below defines the to_supervised() function that implements this functionality. It takes two parameters to specify the number of encoded integers to use as input and output. The number of output integers must be less than or equal to the number of inputs and is counted from the oldest observation.
#
# For example, if 5 and 1 were specified for input and output on the sequence [1, 2, 3, 4, 5], then the function would return a single row in X with [1, 2, 3, 4, 5] and a single row in y with [1].

# %%
# convert encoded sequence to supervised learning
def to_supervised(sequence, n_in, n_out):
	# create lag copies of the sequence
	df = DataFrame(sequence)
	df = concat([df.shift(n_in-i-1) for i in range(n_in)], axis=1)
	# drop rows with missing values
	df.dropna(inplace=True)
	# specify columns for input and output pairs
	values = df.values
	width = sequence.shape[1]
	X = values.reshape(len(values), n_in, width)
	y = values[:, 0:(n_out*width)].reshape(len(values), n_out, width)
	return X, y

# %% [markdown]
# ### Complete Example
# We can tie all of this together.
#
# Below is the complete code listing for generating a sequence of 25 random integers and encoding each integer as a binary vector, separating them into X,y pairs for learning, then printing the decoded pairs for review.

# %%
from random import randint
from numpy import array
from numpy import argmax
from pandas import DataFrame
from pandas import concat
 
# generate a sequence of random numbers in [0, 99]
def generate_sequence(length=25):
	return [randint(0, 99) for _ in range(length)]
 
# one hot encode sequence
def one_hot_encode(sequence, n_unique=100):
	encoding = list()
	for value in sequence:
		vector = [0 for _ in range(n_unique)]
		vector[value] = 1
		encoding.append(vector)
	return array(encoding)
 
# decode a one hot encoded string
def one_hot_decode(encoded_seq):
	return [argmax(vector) for vector in encoded_seq]
 
# convert encoded sequence to supervised learning
def to_supervised(sequence, n_in, n_out):
	# create lag copies of the sequence
	df = DataFrame(sequence)
	df = concat([df.shift(n_in-i-1) for i in range(n_in)], axis=1)
	# drop rows with missing values
	df.dropna(inplace=True)
	# specify columns for input and output pairs
	values = df.values
	width = sequence.shape[1]
	X = values.reshape(len(values), n_in, width)
	y = values[:, 0:(n_out*width)].reshape(len(values), n_out, width)
	return X, y
 
# generate random sequence
sequence = generate_sequence()
print(sequence)
# one hot encode
encoded = one_hot_encode(sequence)
# convert to X,y pairs
X,y = to_supervised(encoded, 5, 3)
# decode all pairs
for i in range(len(X)):
	print(one_hot_decode(X[i]), '=>', one_hot_decode(y[i]))
# Out:
# [59, 47, 23, 54, 30, 53, 98, 39, 9, 44, 28, 18, 33, 72, 28, 73, 12, 98, 45, 34, 2, 99, 80, 49, 5]
# [59, 47, 23, 54, 30] => [59, 47, 23]
# [47, 23, 54, 30, 53] => [47, 23, 54]
# [23, 54, 30, 53, 98] => [23, 54, 30]
# [54, 30, 53, 98, 39] => [54, 30, 53]
# [30, 53, 98, 39, 9] => [30, 53, 98]
# [53, 98, 39, 9, 44] => [53, 98, 39]
# [98, 39, 9, 44, 28] => [98, 39, 9]
# [39, 9, 44, 28, 18] => [39, 9, 44]
# [9, 44, 28, 18, 33] => [9, 44, 28]
# [44, 28, 18, 33, 72] => [44, 28, 18]
# [28, 18, 33, 72, 28] => [28, 18, 33]
# [18, 33, 72, 28, 73] => [18, 33, 72]
# [33, 72, 28, 73, 12] => [33, 72, 28]
# [72, 28, 73, 12, 98] => [72, 28, 73]
# [28, 73, 12, 98, 45] => [28, 73, 12]
# [73, 12, 98, 45, 34] => [73, 12, 98]
# [12, 98, 45, 34, 2] => [12, 98, 45]
# [98, 45, 34, 2, 99] => [98, 45, 34]
# [45, 34, 2, 99, 80] => [45, 34, 2]
# [34, 2, 99, 80, 49] => [34, 2, 99]
# [2, 99, 80, 49, 5] => [2, 99, 80]

# %% [markdown]
# Running the example may produce different specific numbers for you.
#
# The sequence was split into input sequences of 5 numbers and output sequences of the 3 oldest observations from the input sequences.
#
# Now that we know how to prepare and represent random sequences of integers, we can look at using LSTMs to learn them.
#
# ## Echo Whole Sequence (sequence-to-sequence model)
# In this section, we will develop an LSTM for a simple framing of the problem, that is the prediction or reproduction of the entire input sequence.
#
# That is, given a fixed input sequence, such as 5 random integers, output the same sequence. This may not sound like a simple framing of the problem, but it is because the network architecture required to address it is straightforward.
#
# We will generate random sequences of 25 integers and frame them as input-output pairs of 5 values. We will create a convenience function named get_data() that we will use to create encoded X,y pairs of random integers using all of the functionality prepared in the previous section. This function is listed below.

# %%
# prepare data for the LSTM
def get_data(n_in, n_out):
	# generate random sequence
	sequence = generate_sequence()
	# one hot encode
	encoded = one_hot_encode(sequence)
	# convert to X,y pairs
	X,y = to_supervised(encoded, n_in, n_out)
	return X,y

# %% [markdown]
# This function will be called with the parameters 5 and 5 to create 21 samples with 5 timesteps of 100 features as inputs and the same as outputs (21 rather than 25 because some rows with missing values due to the shifting of the sequence are removed).
#
# We can now develop an LSTM for this problem. We will use a stateful LSTM and explicitly reset the internal state at the end of training for each generated sample. Maintaining internal state within the network across the samples in a sequence may or may not be required as the context required for learning will be provided as timesteps; nevertheless, this additional state may be helpful.
#
# Let’s start off by defining the expected dimensions of the input data as 5 timesteps of 100 features. Because we are using a stateful LSTM, this will be specified using the batch_input_shape argument instead of the input_shape. The LSTM hidden layer will use 20 memory units, which should be more than sufficient to learn this problem.
#
# A batch size of 7 will be used. The batch size must be a factor of the number of training samples (in this case 21) and defines the number samples after which the weights in the LSTM are updated. This means weights will be updated 3 times for each random sequence the network is trained on.

# %%
model = Sequential()
model.add(LSTM(20, batch_input_shape=(7, 5, 100), return_sequences=True, stateful=True))

# %% [markdown]
# We want the output layer to output one integer at a time, one for each input observed.
#
# We will define the output layer as a fully connected layer (Dense) with 100 neurons for each of the 100 possible integer values in the one hot encoding. Because we are using a one hot encoding and framing the problem as multi-class classification, we can use the softmax activation function in the Dense layer.

# %%
Dense(100, activation='softmax')

# %% [markdown]
# We need to wrap this output layer in a TimeDistributed layer. This is to ensure that we can use the output layer to predict one integer at a time for each of the items in the input sequence. This is key so that we are implementing a true many-to-many model (e.g. sequence-to-sequence), rather than a many-to-one model where a one-shot vector output is created based on the internal state and value of the last observation in the input sequence (e.g. the output layer outputting 5*100 values at once).
#
# This requires that the previous LSTM layer returns sequences by setting return_sequences=True (e.g. one output for each observation in the input sequence rather than one output for the entire input sequence). The TimeDistributed layer performs the trick of applying each slice of the sequence from the LSTM layer as inputs to the wrapped Dense layer so that one integer can be predicted at a time.

# %%
	
model.add(TimeDistributed(Dense(100, activation='softmax')))

# %% [markdown]
# We will use the log loss function suitable for multi-class classification problems (categorical_crossentropy) and the efficient ADAM optimization algorithm with default hyperparameters.
#
# In addition to reporting the log loss each epoch, we will also report the classification accuracy to get an idea of how our model is training.

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

# %% [markdown]
# To ensure the network does not memorize the problem, and the network learns to generalize a solution for all possible input sequences, we will generate a new random sequence each training epoch. Internal state within the LSTM hidden layer will reset at the end of each epoch. We will fit the model for 500 training epochs.

# %%
# train LSTM
for epoch in range(500):
	# generate new random sequence
	X,y = get_data(5, 5)
	# fit model for one epoch on this sequence
	model.fit(X, y, epochs=1, batch_size=7, verbose=2, shuffle=False)
	model.reset_states()

# %% [markdown]
# Once fit, we will evaluate the model by making a prediction on one new random sequence of integers and compare the decoded expected output sequences to the predicted sequences.

# %%
# evaluate LSTM
X,y = get_data(5, 5)
yhat = model.predict(X, batch_size=7, verbose=0)
# decode all pairs
for i in range(len(X)):
	print('Expected:', one_hot_decode(y[i]), 'Predicted', one_hot_decode(yhat[i]))

# %% [markdown]
# Putting this all together, the complete code listing is provided below.

# %%
from random import randint
from numpy import array
from numpy import argmax
from pandas import DataFrame
from pandas import concat
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
 
# generate a sequence of random numbers in [0, 99]
def generate_sequence(length=25):
	return [randint(0, 99) for _ in range(length)]
 
# one hot encode sequence
def one_hot_encode(sequence, n_unique=100):
	encoding = list()
	for value in sequence:
		vector = [0 for _ in range(n_unique)]
		vector[value] = 1
		encoding.append(vector)
	return array(encoding)
 
# decode a one hot encoded string
def one_hot_decode(encoded_seq):
	return [argmax(vector) for vector in encoded_seq]
 
# convert encoded sequence to supervised learning
def to_supervised(sequence, n_in, n_out):
	# create lag copies of the sequence
	df = DataFrame(sequence)
	df = concat([df.shift(n_in-i-1) for i in range(n_in)], axis=1)
	# drop rows with missing values
	df.dropna(inplace=True)
	# specify columns for input and output pairs
	values = df.values
	width = sequence.shape[1]
	X = values.reshape(len(values), n_in, width)
	y = values[:, 0:(n_out*width)].reshape(len(values), n_out, width)
	return X, y
 
# prepare data for the LSTM
def get_data(n_in, n_out):
	# generate random sequence
	sequence = generate_sequence()
	# one hot encode
	encoded = one_hot_encode(sequence)
	# convert to X,y pairs
	X,y = to_supervised(encoded, n_in, n_out)
	return X,y
 
# define LSTM
n_in = 5
n_out = 5
encoded_length = 100
batch_size = 7
model = Sequential()
model.add(LSTM(20, batch_input_shape=(batch_size, n_in, encoded_length), return_sequences=True, stateful=True))
model.add(TimeDistributed(Dense(encoded_length, activation='softmax')))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])
# train LSTM
for epoch in range(500):
	# generate new random sequence
	X,y = get_data(n_in, n_out)
	# fit model for one epoch on this sequence
	model.fit(X, y, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
	model.reset_states()
# evaluate LSTM
X,y = get_data(n_in, n_out)
yhat = model.predict(X, batch_size=batch_size, verbose=0)
# decode all pairs
for i in range(len(X)):
	print('Expected:', one_hot_decode(y[i]), 'Predicted', one_hot_decode(yhat[i]))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Epoch 1/1
#  - 1s - loss: 4.6039 - acc: 0.0381
# Epoch 1/1
#  - 0s - loss: 4.6045 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6069 - acc: 0.0095
# Epoch 1/1
#  - 0s - loss: 4.6098 - acc: 0.0190
# Epoch 1/1
#  - 0s - loss: 4.6027 - acc: 0.0190
# Epoch 1/1
#  - 0s - loss: 4.6002 - acc: 0.0286
# Epoch 1/1
#  - 0s - loss: 4.6121 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5983 - acc: 0.0190
# Epoch 1/1
#  - 0s - loss: 4.6008 - acc: 0.0381
# Epoch 1/1
#  - 0s - loss: 4.6001 - acc: 0.0762
# Epoch 1/1
#  - 0s - loss: 4.5836 - acc: 0.0286
# Epoch 1/1
#  - 0s - loss: 4.5940 - acc: 0.0190
# Epoch 1/1
#  - 0s - loss: 4.6019 - acc: 0.0190
# Epoch 1/1
#  - 0s - loss: 4.5940 - acc: 0.0095
# Epoch 1/1
#  - 0s - loss: 4.5986 - acc: 0.0095
# Epoch 1/1
#  - 0s - loss: 4.5956 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5862 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.5916 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5920 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5909 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6109 - acc: 0.0095
# Epoch 1/1
#  - 0s - loss: 4.5816 - acc: 0.0667
# Epoch 1/1
#  - 0s - loss: 4.5852 - acc: 0.0095
# Epoch 1/1
#  - 0s - loss: 4.5894 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.6013 - acc: 0.0190
# Epoch 1/1
#  - 0s - loss: 4.5894 - acc: 0.0286
# Epoch 1/1
#  - 0s - loss: 4.5929 - acc: 0.0571
# Epoch 1/1
#  - 0s - loss: 4.5804 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.5874 - acc: 0.0762
# Epoch 1/1
#  - 0s - loss: 4.5945 - acc: 0.0381
# Epoch 1/1
#  - 0s - loss: 4.5879 - acc: 0.0381
# Epoch 1/1
#  - 0s - loss: 4.5809 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.5868 - acc: 0.0762
# Epoch 1/1
#  - 0s - loss: 4.5895 - acc: 0.0190
# Epoch 1/1
#  - 0s - loss: 4.5730 - acc: 0.1238
# Epoch 1/1
#  - 0s - loss: 4.5891 - acc: 0.0571
# Epoch 1/1
#  - 0s - loss: 4.5757 - acc: 0.0857
# Epoch 1/1
#  - 0s - loss: 4.5891 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5848 - acc: 0.0095
# Epoch 1/1
#  - 0s - loss: 4.5581 - acc: 0.2667
# Epoch 1/1
#  - 0s - loss: 4.5798 - acc: 0.0190
# Epoch 1/1
#  - 0s - loss: 4.5728 - acc: 0.1524
# Epoch 1/1
#  - 0s - loss: 4.5819 - acc: 0.0857
# Epoch 1/1
#  - 0s - loss: 4.5718 - acc: 0.1810
# Epoch 1/1
#  - 0s - loss: 4.5653 - acc: 0.1619
# Epoch 1/1
#  - 0s - loss: 4.5672 - acc: 0.1048
# Epoch 1/1
#  - 0s - loss: 4.5643 - acc: 0.1238
# Epoch 1/1
#  - 0s - loss: 4.5797 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.5544 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.5803 - acc: 0.1524
# Epoch 1/1
#  - 0s - loss: 4.5571 - acc: 0.1714
# Epoch 1/1
#  - 0s - loss: 4.5738 - acc: 0.1619
# Epoch 1/1
#  - 0s - loss: 4.5661 - acc: 0.2000
# Epoch 1/1
#  - 0s - loss: 4.5642 - acc: 0.1143
# Epoch 1/1
#  - 0s - loss: 4.5580 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.5604 - acc: 0.1714
# Epoch 1/1
#  - 0s - loss: 4.5714 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.5585 - acc: 0.0762
# Epoch 1/1
#  - 0s - loss: 4.5535 - acc: 0.2095
# Epoch 1/1
#  - 0s - loss: 4.5574 - acc: 0.1619
# Epoch 1/1
#  - 0s - loss: 4.5718 - acc: 0.0667
# Epoch 1/1
#  - 0s - loss: 4.5568 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.5323 - acc: 0.1524
# Epoch 1/1
#  - 0s - loss: 4.5522 - acc: 0.1524
# Epoch 1/1
#  - 0s - loss: 4.5554 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.5447 - acc: 0.2000
# Epoch 1/1
#  - 0s - loss: 4.5467 - acc: 0.1238
# Epoch 1/1
#  - 0s - loss: 4.5602 - acc: 0.0571
# Epoch 1/1
#  - 0s - loss: 4.5337 - acc: 0.2000
# Epoch 1/1
#  - 0s - loss: 4.5582 - acc: 0.1143
# Epoch 1/1
#  - 0s - loss: 4.5498 - acc: 0.0857
# Epoch 1/1
#  - 0s - loss: 4.5230 - acc: 0.2571
# Epoch 1/1
#  - 0s - loss: 4.5333 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 4.5318 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 4.5485 - acc: 0.1238
# Epoch 1/1
#  - 0s - loss: 4.5361 - acc: 0.2000
# Epoch 1/1
#  - 0s - loss: 4.5321 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.5526 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.5275 - acc: 0.2190
# Epoch 1/1
#  - 0s - loss: 4.5333 - acc: 0.2095
# Epoch 1/1
#  - 0s - loss: 4.5303 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.5110 - acc: 0.1524
# Epoch 1/1
#  - 0s - loss: 4.5535 - acc: 0.0095
# Epoch 1/1
#  - 0s - loss: 4.5488 - acc: 0.0762
# Epoch 1/1
#  - 0s - loss: 4.5636 - acc: 0.0286
# Epoch 1/1
#  - 0s - loss: 4.5023 - acc: 0.2952
# Epoch 1/1
#  - 0s - loss: 4.5270 - acc: 0.2476
# Epoch 1/1
#  - 0s - loss: 4.5517 - acc: 0.1810
# Epoch 1/1
#  - 0s - loss: 4.5021 - acc: 0.2286
# Epoch 1/1
#  - 0s - loss: 4.5099 - acc: 0.2667
# Epoch 1/1
#  - 0s - loss: 4.5177 - acc: 0.3238
# Epoch 1/1
#  - 0s - loss: 4.4808 - acc: 0.1810
# Epoch 1/1
#  - 0s - loss: 4.5170 - acc: 0.1524
# Epoch 1/1
#  - 0s - loss: 4.5019 - acc: 0.1048
# Epoch 1/1
#  - 0s - loss: 4.5171 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.5252 - acc: 0.1238
# Epoch 1/1
#  - 0s - loss: 4.4981 - acc: 0.2667
# Epoch 1/1
#  - 0s - loss: 4.5007 - acc: 0.1048
# Epoch 1/1
#  - 0s - loss: 4.4918 - acc: 0.2762
# Epoch 1/1
#  - 0s - loss: 4.4844 - acc: 0.2190
# Epoch 1/1
#  - 0s - loss: 4.4648 - acc: 0.0381
# Epoch 1/1
#  - 0s - loss: 4.4718 - acc: 0.1714
# Epoch 1/1
#  - 0s - loss: 4.4808 - acc: 0.2095
# Epoch 1/1
#  - 0s - loss: 4.4988 - acc: 0.1143
# Epoch 1/1
#  - 0s - loss: 4.4952 - acc: 0.0857
# Epoch 1/1
#  - 0s - loss: 4.5158 - acc: 0.0762
# Epoch 1/1
#  - 0s - loss: 4.4763 - acc: 0.0857
# Epoch 1/1
#  - 0s - loss: 4.4847 - acc: 0.1524
# Epoch 1/1
#  - 0s - loss: 4.4653 - acc: 0.1714
# Epoch 1/1
#  - 0s - loss: 4.4838 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.5042 - acc: 0.1619
# Epoch 1/1
#  - 0s - loss: 4.5037 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.4697 - acc: 0.1714
# Epoch 1/1
#  - 0s - loss: 4.4770 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 4.4892 - acc: 0.1238
# Epoch 1/1
#  - 0s - loss: 4.4374 - acc: 0.2000
# Epoch 1/1
#  - 0s - loss: 4.4597 - acc: 0.1238
# Epoch 1/1
#  - 0s - loss: 4.4546 - acc: 0.2571
# Epoch 1/1
#  - 0s - loss: 4.4896 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 4.4327 - acc: 0.2000
# Epoch 1/1
#  - 0s - loss: 4.4867 - acc: 0.1619
# Epoch 1/1
#  - 0s - loss: 4.4397 - acc: 0.2095
# Epoch 1/1
#  - 0s - loss: 4.4535 - acc: 0.2476
# Epoch 1/1
#  - 0s - loss: 4.4141 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 4.4225 - acc: 0.1524
# Epoch 1/1
#  - 0s - loss: 4.3911 - acc: 0.2476
# Epoch 1/1
#  - 0s - loss: 4.4204 - acc: 0.3905
# Epoch 1/1
#  - 0s - loss: 4.4572 - acc: 0.0857
# Epoch 1/1
#  - 0s - loss: 4.4188 - acc: 0.1714
# Epoch 1/1
#  - 0s - loss: 4.4492 - acc: 0.1048
# Epoch 1/1
#  - 0s - loss: 4.4412 - acc: 0.1619
# Epoch 1/1
#  - 0s - loss: 4.3730 - acc: 0.2762
# Epoch 1/1
#  - 0s - loss: 4.4406 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 4.4641 - acc: 0.2286
# Epoch 1/1
#  - 0s - loss: 4.4432 - acc: 0.1238
# Epoch 1/1
#  - 0s - loss: 4.4065 - acc: 0.3143
# Epoch 1/1
#  - 0s - loss: 4.3734 - acc: 0.1333
# Epoch 1/1
#  - 0s - loss: 4.4154 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 4.4309 - acc: 0.1714
# Epoch 1/1
#  - 0s - loss: 4.4030 - acc: 0.4095
# Epoch 1/1
#  - 0s - loss: 4.3326 - acc: 0.1524
# Epoch 1/1
#  - 0s - loss: 4.4207 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 4.3502 - acc: 0.2190
# Epoch 1/1
#  - 0s - loss: 4.4073 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.3776 - acc: 0.2000
# Epoch 1/1
#  - 0s - loss: 4.3822 - acc: 0.2286
# Epoch 1/1
#  - 0s - loss: 4.2976 - acc: 0.2476
# Epoch 1/1
#  - 0s - loss: 4.4625 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 4.3203 - acc: 0.2095
# Epoch 1/1
#  - 0s - loss: 4.3105 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 4.3128 - acc: 0.2190
# Epoch 1/1
#  - 0s - loss: 4.3006 - acc: 0.2476
# Epoch 1/1
#  - 0s - loss: 4.2375 - acc: 0.2286
# Epoch 1/1
#  - 0s - loss: 4.3277 - acc: 0.3048
# Epoch 1/1
#  - 0s - loss: 4.4146 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 4.3822 - acc: 0.1619
# Epoch 1/1
#  - 0s - loss: 4.3983 - acc: 0.2190
# Epoch 1/1
#  - 0s - loss: 4.3639 - acc: 0.2095
# Epoch 1/1
#  - 0s - loss: 4.3058 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 4.3071 - acc: 0.2095
# Epoch 1/1
#  - 0s - loss: 4.3178 - acc: 0.1714
# Epoch 1/1
#  - 0s - loss: 4.2903 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 4.2745 - acc: 0.2952
# Epoch 1/1
#  - 0s - loss: 4.3205 - acc: 0.2952
# Epoch 1/1
#  - 0s - loss: 4.3117 - acc: 0.2571
# Epoch 1/1
#  - 0s - loss: 4.2875 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 4.2755 - acc: 0.3048
# Epoch 1/1
#  - 0s - loss: 4.3351 - acc: 0.2095
# Epoch 1/1
#  - 0s - loss: 4.2559 - acc: 0.2762
# Epoch 1/1
#  - 0s - loss: 4.2514 - acc: 0.1810
# Epoch 1/1
#  - 0s - loss: 4.2947 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 4.2120 - acc: 0.3048
# Epoch 1/1
#  - 0s - loss: 4.2954 - acc: 0.3524
# Epoch 1/1
#  - 0s - loss: 4.2691 - acc: 0.3143
# Epoch 1/1
#  - 0s - loss: 4.2772 - acc: 0.2667
# Epoch 1/1
#  - 0s - loss: 4.3815 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.2124 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 4.2092 - acc: 0.2762
# Epoch 1/1
#  - 0s - loss: 4.1343 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 4.2861 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.2774 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 4.1681 - acc: 0.2571
# Epoch 1/1
#  - 0s - loss: 4.1969 - acc: 0.4095
# Epoch 1/1
#  - 0s - loss: 4.2280 - acc: 0.3524
# Epoch 1/1
#  - 0s - loss: 4.2195 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 4.2628 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 4.1088 - acc: 0.4571
# Epoch 1/1
#  - 0s - loss: 4.1096 - acc: 0.4857
# Epoch 1/1
#  - 0s - loss: 4.2620 - acc: 0.2762
# Epoch 1/1
#  - 0s - loss: 4.1471 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 4.2982 - acc: 0.2190
# Epoch 1/1
#  - 0s - loss: 3.9237 - acc: 0.4571
# Epoch 1/1
#  - 0s - loss: 4.1025 - acc: 0.2571
# Epoch 1/1
#  - 0s - loss: 4.0079 - acc: 0.3714
# Epoch 1/1
#  - 0s - loss: 4.1551 - acc: 0.2571
# Epoch 1/1
#  - 0s - loss: 4.1291 - acc: 0.2952
# Epoch 1/1
#  - 0s - loss: 4.2492 - acc: 0.2762
# Epoch 1/1
#  - 0s - loss: 4.1330 - acc: 0.4476
# Epoch 1/1
#  - 0s - loss: 4.0350 - acc: 0.2476
# Epoch 1/1
#  - 0s - loss: 4.0581 - acc: 0.3238
# Epoch 1/1
#  - 0s - loss: 4.2520 - acc: 0.3048
# Epoch 1/1
#  - 0s - loss: 3.9312 - acc: 0.4952
# Epoch 1/1
#  - 0s - loss: 4.0070 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 4.1960 - acc: 0.2476
# Epoch 1/1
#  - 0s - loss: 4.1047 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 4.1454 - acc: 0.3714
# Epoch 1/1
#  - 0s - loss: 4.0425 - acc: 0.3714
# Epoch 1/1
#  - 0s - loss: 4.0813 - acc: 0.4476
# Epoch 1/1
#  - 0s - loss: 4.1841 - acc: 0.1810
# Epoch 1/1
#  - 0s - loss: 4.0417 - acc: 0.3048
# Epoch 1/1
#  - 0s - loss: 4.0524 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 4.0901 - acc: 0.3714
# Epoch 1/1
#  - 0s - loss: 4.1319 - acc: 0.2762
# Epoch 1/1
#  - 0s - loss: 4.0268 - acc: 0.2952
# Epoch 1/1
#  - 0s - loss: 4.1377 - acc: 0.3143
# Epoch 1/1
#  - 0s - loss: 4.0756 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 4.1157 - acc: 0.4571
# Epoch 1/1
#  - 0s - loss: 4.0663 - acc: 0.3048
# Epoch 1/1
#  - 0s - loss: 3.9366 - acc: 0.3905
# Epoch 1/1
#  - 0s - loss: 4.0383 - acc: 0.3048
# Epoch 1/1
#  - 0s - loss: 4.0557 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 3.9118 - acc: 0.3524
# Epoch 1/1
#  - 0s - loss: 3.9729 - acc: 0.4667
# Epoch 1/1
#  - 0s - loss: 4.0411 - acc: 0.4190
# Epoch 1/1
#  - 0s - loss: 3.9980 - acc: 0.3524
# Epoch 1/1
#  - 0s - loss: 3.8710 - acc: 0.4476
# Epoch 1/1
#  - 0s - loss: 3.9853 - acc: 0.3905
# Epoch 1/1
#  - 0s - loss: 3.9571 - acc: 0.4095
# Epoch 1/1
#  - 0s - loss: 4.0113 - acc: 0.3619
# Epoch 1/1
#  - 0s - loss: 4.0218 - acc: 0.4095
# Epoch 1/1
#  - 0s - loss: 3.9622 - acc: 0.3714
# Epoch 1/1
#  - 0s - loss: 3.9772 - acc: 0.3619
# Epoch 1/1
#  - 0s - loss: 3.8927 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 3.9444 - acc: 0.3714
# Epoch 1/1
#  - 0s - loss: 3.8564 - acc: 0.5048
# Epoch 1/1
#  - 0s - loss: 3.9256 - acc: 0.4667
# Epoch 1/1
#  - 0s - loss: 3.8999 - acc: 0.4857
# Epoch 1/1
#  - 0s - loss: 4.0113 - acc: 0.4667
# Epoch 1/1
#  - 0s - loss: 3.9227 - acc: 0.4571
# Epoch 1/1
#  - 0s - loss: 3.9652 - acc: 0.5048
# Epoch 1/1
#  - 0s - loss: 3.9197 - acc: 0.3524
# Epoch 1/1
#  - 0s - loss: 3.9126 - acc: 0.4000
# Epoch 1/1
#  - 0s - loss: 3.8414 - acc: 0.5143
# Epoch 1/1
#  - 0s - loss: 3.9015 - acc: 0.4952
# Epoch 1/1
#  - 0s - loss: 4.0174 - acc: 0.4190
# Epoch 1/1
#  - 0s - loss: 3.7729 - acc: 0.6667
# Epoch 1/1
#  - 0s - loss: 3.8513 - acc: 0.5810
# Epoch 1/1
#  - 0s - loss: 3.9140 - acc: 0.5048
# Epoch 1/1
#  - 0s - loss: 3.9138 - acc: 0.3619
# Epoch 1/1
#  - 0s - loss: 3.8080 - acc: 0.6286
# Epoch 1/1
#  - 0s - loss: 3.8042 - acc: 0.5143
# Epoch 1/1
#  - 0s - loss: 3.8867 - acc: 0.3714
# Epoch 1/1
#  - 0s - loss: 3.9127 - acc: 0.6286
# Epoch 1/1
#  - 0s - loss: 3.9071 - acc: 0.4476
# Epoch 1/1
#  - 0s - loss: 3.7663 - acc: 0.4667
# Epoch 1/1
#  - 0s - loss: 3.8102 - acc: 0.4857
# Epoch 1/1
#  - 0s - loss: 3.8558 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 3.7624 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 3.9522 - acc: 0.3143
# Epoch 1/1
#  - 0s - loss: 3.7018 - acc: 0.5524
# Epoch 1/1
#  - 0s - loss: 3.8833 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 3.7309 - acc: 0.6476
# Epoch 1/1
#  - 0s - loss: 3.7142 - acc: 0.6952
# Epoch 1/1
#  - 0s - loss: 3.7217 - acc: 0.5429
# Epoch 1/1
#  - 0s - loss: 3.7446 - acc: 0.5810
# Epoch 1/1
#  - 0s - loss: 3.8203 - acc: 0.4095
# Epoch 1/1
#  - 0s - loss: 3.7016 - acc: 0.7048
# Epoch 1/1
#  - 0s - loss: 3.7569 - acc: 0.5143
# Epoch 1/1
#  - 0s - loss: 3.8138 - acc: 0.5524
# Epoch 1/1
#  - 0s - loss: 3.7817 - acc: 0.5905
# Epoch 1/1
#  - 0s - loss: 3.7214 - acc: 0.6381
# Epoch 1/1
#  - 0s - loss: 3.6814 - acc: 0.5714
# Epoch 1/1
#  - 0s - loss: 3.7106 - acc: 0.5905
# Epoch 1/1
#  - 0s - loss: 3.6318 - acc: 0.6762
# Epoch 1/1
#  - 0s - loss: 3.6817 - acc: 0.5714
# Epoch 1/1
#  - 0s - loss: 3.7444 - acc: 0.6381
# Epoch 1/1
#  - 0s - loss: 3.6920 - acc: 0.6381
# Epoch 1/1
#  - 0s - loss: 3.6904 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.8020 - acc: 0.4381
# Epoch 1/1
#  - 0s - loss: 3.7134 - acc: 0.6286
# Epoch 1/1
#  - 0s - loss: 3.6272 - acc: 0.6286
# Epoch 1/1
#  - 0s - loss: 3.5633 - acc: 0.7238
# Epoch 1/1
#  - 0s - loss: 3.7576 - acc: 0.4381
# Epoch 1/1
#  - 0s - loss: 3.6027 - acc: 0.7048
# Epoch 1/1
#  - 0s - loss: 3.5709 - acc: 0.5619
# Epoch 1/1
#  - 0s - loss: 3.7676 - acc: 0.6095
# Epoch 1/1
#  - 0s - loss: 3.6902 - acc: 0.6286
# Epoch 1/1
#  - 0s - loss: 3.6916 - acc: 0.6762
# Epoch 1/1
#  - 0s - loss: 3.5196 - acc: 0.8190
# Epoch 1/1
#  - 0s - loss: 3.7377 - acc: 0.6762
# Epoch 1/1
#  - 0s - loss: 3.6325 - acc: 0.5810
# Epoch 1/1
#  - 0s - loss: 3.5092 - acc: 0.7238
# Epoch 1/1
#  - 0s - loss: 3.6112 - acc: 0.7333
# Epoch 1/1
#  - 0s - loss: 3.6590 - acc: 0.7905
# Epoch 1/1
#  - 0s - loss: 3.5721 - acc: 0.7810
# Epoch 1/1
#  - 0s - loss: 3.6315 - acc: 0.6476
# Epoch 1/1
#  - 0s - loss: 3.7101 - acc: 0.5714
# Epoch 1/1
#  - 0s - loss: 3.6676 - acc: 0.5714
# Epoch 1/1
#  - 0s - loss: 3.6186 - acc: 0.5905
# Epoch 1/1
#  - 0s - loss: 3.6673 - acc: 0.6190
# Epoch 1/1
#  - 0s - loss: 3.5882 - acc: 0.6857
# Epoch 1/1
#  - 0s - loss: 3.5576 - acc: 0.6762
# Epoch 1/1
#  - 0s - loss: 3.6078 - acc: 0.7048
# Epoch 1/1
#  - 0s - loss: 3.6276 - acc: 0.6952
# Epoch 1/1
#  - 0s - loss: 3.5572 - acc: 0.7238
# Epoch 1/1
#  - 0s - loss: 3.5399 - acc: 0.6952
# Epoch 1/1
#  - 0s - loss: 3.4618 - acc: 0.7429
# Epoch 1/1
#  - 0s - loss: 3.4096 - acc: 0.8476
# Epoch 1/1
#  - 0s - loss: 3.4402 - acc: 0.8095
# Epoch 1/1
#  - 0s - loss: 3.5395 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.4599 - acc: 0.6857
# Epoch 1/1
#  - 0s - loss: 3.5473 - acc: 0.7048
# Epoch 1/1
#  - 0s - loss: 3.4303 - acc: 0.8381
# Epoch 1/1
#  - 0s - loss: 3.2550 - acc: 0.7429
# Epoch 1/1
#  - 0s - loss: 3.3662 - acc: 0.8571
# Epoch 1/1
#  - 0s - loss: 3.5153 - acc: 0.6667
# Epoch 1/1
#  - 0s - loss: 3.4878 - acc: 0.7143
# Epoch 1/1
#  - 0s - loss: 3.3871 - acc: 0.7143
# Epoch 1/1
#  - 0s - loss: 3.3678 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 3.4294 - acc: 0.7333
# Epoch 1/1
#  - 0s - loss: 3.3782 - acc: 0.8286
# Epoch 1/1
#  - 0s - loss: 3.4760 - acc: 0.6476
# Epoch 1/1
#  - 0s - loss: 3.4529 - acc: 0.7333
# Epoch 1/1
#  - 0s - loss: 3.4232 - acc: 0.7714
# Epoch 1/1
#  - 0s - loss: 3.3215 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 3.3402 - acc: 0.8667
# Epoch 1/1
#  - 0s - loss: 3.4133 - acc: 0.7619
# Epoch 1/1
#  - 0s - loss: 3.2068 - acc: 0.8286
# Epoch 1/1
#  - 0s - loss: 3.3153 - acc: 0.8952
# Epoch 1/1
#  - 0s - loss: 3.4377 - acc: 0.7619
# Epoch 1/1
#  - 0s - loss: 3.3705 - acc: 0.6571
# Epoch 1/1
#  - 0s - loss: 3.2888 - acc: 0.8667
# Epoch 1/1
#  - 0s - loss: 3.3154 - acc: 0.8476
# Epoch 1/1
#  - 0s - loss: 3.3459 - acc: 0.8095
# Epoch 1/1
#  - 0s - loss: 3.2449 - acc: 0.9429
# Epoch 1/1
#  - 0s - loss: 3.3475 - acc: 0.7333
# Epoch 1/1
#  - 0s - loss: 3.2781 - acc: 0.7810
# Epoch 1/1
#  - 0s - loss: 3.2391 - acc: 0.8190
# Epoch 1/1
#  - 0s - loss: 3.2769 - acc: 0.8381
# Epoch 1/1
#  - 0s - loss: 3.3671 - acc: 0.7810
# Epoch 1/1
#  - 0s - loss: 3.3066 - acc: 0.7905
# Epoch 1/1
#  - 0s - loss: 3.2996 - acc: 0.8381
# Epoch 1/1
#  - 0s - loss: 3.2854 - acc: 0.9238
# Epoch 1/1
#  - 0s - loss: 3.2770 - acc: 0.6857
# Epoch 1/1
#  - 0s - loss: 3.1556 - acc: 0.8762
# Epoch 1/1
#  - 0s - loss: 3.4218 - acc: 0.6095
# Epoch 1/1
#  - 0s - loss: 3.3887 - acc: 0.7429
# Epoch 1/1
#  - 0s - loss: 3.0867 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 3.1511 - acc: 0.8667
# Epoch 1/1
#  - 0s - loss: 3.2411 - acc: 0.8190
# Epoch 1/1
#  - 0s - loss: 3.1576 - acc: 0.8667
# Epoch 1/1
#  - 0s - loss: 3.1590 - acc: 0.9238
# Epoch 1/1
#  - 0s - loss: 3.1517 - acc: 0.8381
# Epoch 1/1
#  - 0s - loss: 3.3220 - acc: 0.8095
# Epoch 1/1
#  - 0s - loss: 3.0893 - acc: 0.9333
# Epoch 1/1
#  - 0s - loss: 3.2044 - acc: 0.8952
# Epoch 1/1
#  - 0s - loss: 3.1891 - acc: 0.8571
# Epoch 1/1
#  - 0s - loss: 3.0662 - acc: 0.8952
# Epoch 1/1
#  - 0s - loss: 3.2660 - acc: 0.7905
# Epoch 1/1
#  - 0s - loss: 3.2276 - acc: 0.7048
# Epoch 1/1
#  - 0s - loss: 3.1253 - acc: 0.7905
# Epoch 1/1
#  - 0s - loss: 3.0863 - acc: 0.8762
# Epoch 1/1
#  - 0s - loss: 3.1876 - acc: 0.7238
# Epoch 1/1
#  - 0s - loss: 3.1853 - acc: 0.8571
# Epoch 1/1
#  - 0s - loss: 3.2754 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 3.1632 - acc: 0.8667
# Epoch 1/1
#  - 0s - loss: 3.2154 - acc: 0.9429
# Epoch 1/1
#  - 0s - loss: 3.0901 - acc: 0.8476
# Epoch 1/1
#  - 0s - loss: 2.9570 - acc: 0.8571
# Epoch 1/1
#  - 0s - loss: 3.0298 - acc: 0.8571
# Epoch 1/1
#  - 0s - loss: 3.0166 - acc: 0.9238
# Epoch 1/1
#  - 0s - loss: 3.1472 - acc: 0.8476
# Epoch 1/1
#  - 0s - loss: 3.0520 - acc: 0.9238
# Epoch 1/1
#  - 0s - loss: 3.0599 - acc: 0.9238
# Epoch 1/1
#  - 0s - loss: 3.0499 - acc: 0.9238
# Epoch 1/1
#  - 0s - loss: 3.2006 - acc: 0.8286
# Epoch 1/1
#  - 0s - loss: 2.9886 - acc: 0.8762
# Epoch 1/1
#  - 0s - loss: 3.1275 - acc: 0.9333
# Epoch 1/1
#  - 0s - loss: 3.0788 - acc: 0.8857
# Epoch 1/1
#  - 0s - loss: 3.1363 - acc: 0.8762
# Epoch 1/1
#  - 0s - loss: 3.0292 - acc: 0.8952
# Epoch 1/1
#  - 0s - loss: 3.0285 - acc: 0.9238
# Epoch 1/1
#  - 0s - loss: 3.2217 - acc: 0.8381
# Epoch 1/1
#  - 0s - loss: 3.0627 - acc: 0.9238
# Epoch 1/1
#  - 0s - loss: 3.0720 - acc: 0.8857
# Epoch 1/1
#  - 0s - loss: 2.9535 - acc: 0.8667
# Epoch 1/1
#  - 0s - loss: 2.8177 - acc: 0.9333
# Epoch 1/1
#  - 0s - loss: 2.8373 - acc: 0.9333
# Epoch 1/1
#  - 0s - loss: 3.0112 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 2.9892 - acc: 0.8857
# Epoch 1/1
#  - 0s - loss: 2.9440 - acc: 0.8571
# Epoch 1/1
#  - 0s - loss: 2.8468 - acc: 0.9810
# Epoch 1/1
#  - 0s - loss: 2.8872 - acc: 0.9429
# Epoch 1/1
#  - 0s - loss: 2.9236 - acc: 0.8952
# Epoch 1/1
#  - 0s - loss: 2.8226 - acc: 0.9905
# Epoch 1/1
#  - 0s - loss: 3.0934 - acc: 0.8476
# Epoch 1/1
#  - 0s - loss: 2.8835 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 2.9526 - acc: 0.9429
# Epoch 1/1
#  - 0s - loss: 2.9588 - acc: 0.9619
# Epoch 1/1
#  - 0s - loss: 2.7891 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 2.8824 - acc: 0.9429
# Epoch 1/1
#  - 0s - loss: 2.8191 - acc: 0.9238
# Epoch 1/1
#  - 0s - loss: 2.8083 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 2.6236 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 3.0447 - acc: 0.8476
# Epoch 1/1
#  - 0s - loss: 2.9588 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 2.8167 - acc: 0.8762
# Epoch 1/1
#  - 0s - loss: 2.7928 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 2.9409 - acc: 0.8667
# Epoch 1/1
#  - 0s - loss: 2.9249 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 2.7239 - acc: 0.9238
# Epoch 1/1
#  - 0s - loss: 2.8559 - acc: 0.9619
# Epoch 1/1
#  - 0s - loss: 2.9692 - acc: 0.8667
# Epoch 1/1
#  - 0s - loss: 2.8512 - acc: 0.9333
# Epoch 1/1
#  - 0s - loss: 2.6026 - acc: 0.9429
# Epoch 1/1
#  - 0s - loss: 2.7597 - acc: 0.9619
# Epoch 1/1
#  - 0s - loss: 2.8997 - acc: 0.9143
# Epoch 1/1
#  - 0s - loss: 2.7809 - acc: 0.9143
# Epoch 1/1
#  - 0s - loss: 2.5921 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 2.6375 - acc: 0.9810
# Epoch 1/1
#  - 0s - loss: 2.6991 - acc: 0.9333
# Epoch 1/1
#  - 0s - loss: 2.7731 - acc: 0.9905
# Epoch 1/1
#  - 0s - loss: 2.7426 - acc: 0.9810
# Epoch 1/1
#  - 0s - loss: 2.5977 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.8018 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.7116 - acc: 0.9429
# Epoch 1/1
#  - 0s - loss: 2.6248 - acc: 0.9714
# Epoch 1/1
#  - 0s - loss: 2.7402 - acc: 0.9333
# Epoch 1/1
#  - 0s - loss: 2.7571 - acc: 0.9429
# Epoch 1/1
#  - 0s - loss: 2.6569 - acc: 0.9333
# Epoch 1/1
#  - 0s - loss: 2.6172 - acc: 0.9810
# Epoch 1/1
#  - 0s - loss: 2.6002 - acc: 0.9143
# Epoch 1/1
#  - 0s - loss: 2.4831 - acc: 0.9619
# Epoch 1/1
#  - 0s - loss: 2.6251 - acc: 0.9810
# Epoch 1/1
#  - 0s - loss: 2.5118 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 2.5272 - acc: 0.9619
# Epoch 1/1
#  - 0s - loss: 2.7003 - acc: 0.8857
# Epoch 1/1
#  - 0s - loss: 2.4811 - acc: 0.9810
# Epoch 1/1
#  - 0s - loss: 2.4305 - acc: 0.9429
# Epoch 1/1
#  - 0s - loss: 2.6763 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.7518 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 2.6399 - acc: 0.9429
# Epoch 1/1
#  - 0s - loss: 2.5085 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.6519 - acc: 0.9619
# Epoch 1/1
#  - 0s - loss: 2.5778 - acc: 0.9619
# Epoch 1/1
#  - 0s - loss: 2.4723 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.6838 - acc: 0.9238
# Epoch 1/1
#  - 0s - loss: 2.5058 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 2.3562 - acc: 0.9429
# Epoch 1/1
#  - 0s - loss: 2.4706 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.3740 - acc: 0.9619
# Epoch 1/1
#  - 0s - loss: 2.3306 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.5738 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.5684 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.3517 - acc: 0.9905
# Epoch 1/1
#  - 0s - loss: 2.4659 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.4989 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.4547 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.3642 - acc: 0.9810
# Epoch 1/1
#  - 0s - loss: 2.3450 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 2.2391 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.2050 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.4184 - acc: 0.9905
# Epoch 1/1
#  - 0s - loss: 2.3624 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.2813 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.4461 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 2.4528 - acc: 0.8857
# Epoch 1/1
#  - 0s - loss: 2.4816 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.3288 - acc: 0.8857
# Epoch 1/1
#  - 0s - loss: 2.2388 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.3123 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.2653 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 2.3700 - acc: 0.9714
# Epoch 1/1
#  - 0s - loss: 2.3151 - acc: 0.9905
# Epoch 1/1
#  - 0s - loss: 2.1248 - acc: 0.9238
# Epoch 1/1
#  - 0s - loss: 2.2880 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 2.3230 - acc: 0.9714
# Epoch 1/1
#  - 0s - loss: 2.4876 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 2.2286 - acc: 0.9810
# Epoch 1/1
#  - 0s - loss: 2.2215 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.3228 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.3298 - acc: 0.9905
# Epoch 1/1
#  - 0s - loss: 2.2259 - acc: 0.9714
# Epoch 1/1
#  - 0s - loss: 2.3087 - acc: 0.9333
# Epoch 1/1
#  - 0s - loss: 2.2588 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.2464 - acc: 0.9810
# Epoch 1/1
#  - 0s - loss: 2.1631 - acc: 0.9905
# Epoch 1/1
#  - 0s - loss: 2.3548 - acc: 0.9619
# Epoch 1/1
#  - 0s - loss: 2.2046 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.1503 - acc: 0.9905
# Epoch 1/1
#  - 0s - loss: 2.0536 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.2366 - acc: 0.9619
# Epoch 1/1
#  - 0s - loss: 2.1459 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.1059 - acc: 0.9810
# Epoch 1/1
#  - 0s - loss: 2.1362 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.1871 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.2237 - acc: 0.9810
# Epoch 1/1
#  - 0s - loss: 1.9629 - acc: 0.9905
# Epoch 1/1
#  - 0s - loss: 2.0619 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 2.2261 - acc: 0.9619
# Expected: [48, 19, 18, 1, 35] Predicted [48, 19, 18, 1, 35]
# Expected: [19, 18, 1, 35, 88] Predicted [19, 18, 1, 35, 88]
# Expected: [18, 1, 35, 88, 69] Predicted [18, 1, 35, 88, 69]
# Expected: [1, 35, 88, 69, 41] Predicted [1, 35, 88, 69, 41]
# Expected: [35, 88, 69, 41, 42] Predicted [35, 88, 69, 41, 42]
# Expected: [88, 69, 41, 42, 29] Predicted [88, 69, 41, 42, 29]
# Expected: [69, 41, 42, 29, 15] Predicted [69, 41, 42, 29, 15]
# Expected: [41, 42, 29, 15, 47] Predicted [41, 42, 29, 15, 47]
# Expected: [42, 29, 15, 47, 97] Predicted [42, 29, 15, 47, 97]
# Expected: [29, 15, 47, 97, 95] Predicted [29, 15, 47, 97, 95]
# Expected: [15, 47, 97, 95, 43] Predicted [15, 47, 97, 95, 43]
# Expected: [47, 97, 95, 43, 7] Predicted [47, 97, 95, 43, 7]
# Expected: [97, 95, 43, 7, 81] Predicted [97, 95, 43, 7, 81]
# Expected: [95, 43, 7, 81, 25] Predicted [95, 43, 7, 81, 25]
# Expected: [43, 7, 81, 25, 20] Predicted [43, 7, 81, 25, 20]
# Expected: [7, 81, 25, 20, 65] Predicted [7, 81, 25, 20, 65]
# Expected: [81, 25, 20, 65, 29] Predicted [81, 25, 20, 65, 29]
# Expected: [25, 20, 65, 29, 40] Predicted [25, 20, 65, 29, 40]
# Expected: [20, 65, 29, 40, 63] Predicted [20, 65, 29, 40, 63]
# Expected: [65, 29, 40, 63, 49] Predicted [65, 29, 40, 63, 49]
# Expected: [29, 40, 63, 49, 76] Predicted [29, 40, 63, 49, 76]

# %% [markdown]
# Running the example prints the log loss and accuracy each epoch. The run ends by generating a new random sequence and comparing expected sequences to predicted sequences.
#
# Given the chosen configuration, the network will converge to 100% accuracy pretty much every time it is run. Note, you may see a different final sequence and final log loss.
#
# ## Echo Partial Sequence(encoder-decoder model)
# So far, so good, but what if we want the length of the output sequence to differ from the length of the input sequence?
#
# That is, we want to echo the first 2 observations from the input sequence of 5 observations:

# %%
[1, 2, 3, 4, 5] => [1, 2]

# %% [markdown]
# This is still a sequence-to-sequence prediction problem, but requires a change to the network architecture.
#
# One way would be to have the output sequence the same length, and use padding to fill out the output sequence to the same length.
#
# Alternately we can use a more elegant solution. We can implement an encoder-decoder network that allows a variable length output where an encoder learns an internal representation for the input sequence and the decoder reads the internal representation and learns how to create the output sequence of the same or differing length.
#
# This is a more challenging problem for the network to solve, and in turn requires additional capacity (more memory units) and longer training (more epochs).
#
# The input, first hidden LSTM layer, and TimeDistributed Dense output layer of the network stay the same, except we will increase the number of memory units from 20 to 150. We will also increase the batch size from 7 to 21 so that weight updates are performed at the end of all samples of a random sequence. This was found to result in faster learning for this network after some experimentation.

# %%
model.add(LSTM(150, batch_input_shape=(21, 5, 100), stateful=True))
...
model.add(TimeDistributed(Dense(100, activation='softmax')))

# %% [markdown]
# The first hidden layer is the encoder.
#
# We must add an additional hidden LSTM layer to act as the decoder. Again, we will use 150 memory units in this layer, and as in the previous example, the layer before the TimeDistributed layer will return sequences instead of a single value.

# %%
model.add(LSTM(150, return_sequences=True, stateful=True))

# %% [markdown]
# These two layers do not fit neatly together. The encoder layer will output a 2D array (21, 150) and the decoder expects a 3D array as input (21, ?, 150).
#
# We address this problem by adding a RepeatVector() layer between the encoder and decoder and ensure that the output of the encoder is repeated a suitable number of times to match the length of the output sequence. In this case, 2 times for the two timesteps in the output sequence.

# %%
model.add(RepeatVector(2))

# %% [markdown]
# The LSTM network is therefore defined as:

# %%
model = Sequential()
model.add(LSTM(150, batch_input_shape=(21, 5, 100), stateful=True))
model.add(RepeatVector(2))
model.add(LSTM(150, return_sequences=True, stateful=True))
model.add(TimeDistributed(Dense(100, activation='softmax')))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

# %% [markdown]
# The number of training epochs was increased from 500 to 5,000 to account for the additional capacity of the network.
#
# The rest of the example is the same.
#
# Tying this together, the complete code listing is provided below.

# %%
from random import randint
from numpy import array
from numpy import argmax
from pandas import DataFrame
from pandas import concat
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
from keras.layers import RepeatVector
 
# generate a sequence of random numbers in [0, 99]
def generate_sequence(length=25):
	return [randint(0, 99) for _ in range(length)]
 
# one hot encode sequence
def one_hot_encode(sequence, n_unique=100):
	encoding = list()
	for value in sequence:
		vector = [0 for _ in range(n_unique)]
		vector[value] = 1
		encoding.append(vector)
	return array(encoding)
 
# decode a one hot encoded string
def one_hot_decode(encoded_seq):
	return [argmax(vector) for vector in encoded_seq]
 
# convert encoded sequence to supervised learning
def to_supervised(sequence, n_in, n_out):
	# create lag copies of the sequence
	df = DataFrame(sequence)
	df = concat([df.shift(n_in-i-1) for i in range(n_in)], axis=1)
	# drop rows with missing values
	df.dropna(inplace=True)
	# specify columns for input and output pairs
	values = df.values
	width = sequence.shape[1]
	X = values.reshape(len(values), n_in, width)
	y = values[:, 0:(n_out*width)].reshape(len(values), n_out, width)
	return X, y
 
# prepare data for the LSTM
def get_data(n_in, n_out):
	# generate random sequence
	sequence = generate_sequence()
	# one hot encode
	encoded = one_hot_encode(sequence)
	# convert to X,y pairs
	X,y = to_supervised(encoded, n_in, n_out)
	return X,y
 
# define LSTM
n_in = 5
n_out = 2
encoded_length = 100
batch_size = 21
model = Sequential()
model.add(LSTM(150, batch_input_shape=(batch_size, n_in, encoded_length), stateful=True))
model.add(RepeatVector(n_out))
model.add(LSTM(150, return_sequences=True, stateful=True))
model.add(TimeDistributed(Dense(encoded_length, activation='softmax')))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])
# train LSTM
for epoch in range(5000):
	# generate new random sequence
	X,y = get_data(n_in, n_out)
	# fit model for one epoch on this sequence
	model.fit(X, y, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
	model.reset_states()
# evaluate LSTM
X,y = get_data(n_in, n_out)
yhat = model.predict(X, batch_size=batch_size, verbose=0)
# decode all pairs
for i in range(len(X)):
	print('Expected:', one_hot_decode(y[i]), 'Predicted', one_hot_decode(yhat[i]))
# Out:
# Epoch 1/1
#  - 2s - loss: 4.6077 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6061 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6057 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6023 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6032 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.6063 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5992 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.6049 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.6011 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6029 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6047 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.6035 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6025 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.6016 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6000 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6089 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.6022 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.6011 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.6111 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5984 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6045 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.6045 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5985 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.6047 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5994 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.5987 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 4.6036 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.6045 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6032 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6109 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6019 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6016 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.6047 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6076 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.6021 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6052 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.5959 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6050 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6003 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.5995 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5952 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5986 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 4.5952 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5983 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.6060 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5917 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5968 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5962 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.6004 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5984 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5980 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5925 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5898 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5989 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5945 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5860 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.5952 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6019 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5947 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5944 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5896 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5916 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.5871 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5935 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5917 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.6114 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5811 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6024 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5984 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6070 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.6044 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5860 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.5669 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5951 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5809 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5987 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5944 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5795 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5802 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5895 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5812 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5951 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5696 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5488 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5780 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.5790 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.5725 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5517 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5783 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5636 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.5612 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5774 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5670 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5454 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5426 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5583 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5697 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5069 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5787 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.5665 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5871 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5176 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5035 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.5597 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 4.5211 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.4461 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.4770 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.4373 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5720 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5516 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.4669 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5247 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.5466 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.4343 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.4791 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.4154 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.4828 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.4902 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.2983 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.4997 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.4798 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.5603 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5228 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5130 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.4002 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.4352 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.5059 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.3987 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.4838 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.4844 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.4609 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5099 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.5040 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.4968 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 4.4537 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.5119 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.4727 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.4062 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.4602 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.3370 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.4675 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.3308 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.4016 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.4499 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.2517 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 4.4120 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.4542 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.4534 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.3134 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.3999 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.3459 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.3163 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.4238 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.2551 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.1729 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.2860 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.3814 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.3025 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.4386 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.1047 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 4.3390 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 4.2294 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.3008 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 3.8935 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 4.3113 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.1394 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.1299 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.1471 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.2355 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.2736 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.4106 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.2781 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.0619 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 4.2916 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.3075 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.1829 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.2468 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 3.9797 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 4.3042 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 3.9474 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.2141 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.0663 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.3171 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 3.7696 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.9584 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 4.1005 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 4.1421 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.1031 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 3.9431 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 4.2801 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.1669 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 4.2092 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 4.2011 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 4.0353 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 3.7745 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 3.7910 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 4.1357 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.0346 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 4.0780 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.9349 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 3.9211 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 4.2102 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 3.9338 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 3.9276 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 4.1933 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.1045 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 3.8416 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.7256 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 3.8895 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 4.0700 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 3.8564 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 3.6081 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.8780 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 3.9783 - acc: 0.0476
# Epoch 1/1
#  - 0s - loss: 3.9749 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 3.9020 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 3.9313 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 3.6058 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.9751 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.7264 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.9206 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.6877 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.6592 - acc: 0.0238
# Epoch 1/1
#  - 0s - loss: 3.9243 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 4.0320 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 3.7836 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 4.0550 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.5375 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.6907 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.7179 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.5789 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.7376 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 3.5749 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.5551 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.7823 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 3.8823 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 3.6298 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.8327 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.9149 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.4660 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.5392 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.4280 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.6819 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 3.6384 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 4.1423 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.6975 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.8404 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.5395 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.6528 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.4713 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.4152 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.4157 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.8618 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.4620 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.9551 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 3.5016 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.8546 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.5612 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 3.8786 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.7398 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.2445 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.4279 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.5085 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.7189 - acc: 0.0952
# Epoch 1/1
#  - 0s - loss: 3.6606 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 3.4814 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.7816 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.7166 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.7709 - acc: 0.0714
# Epoch 1/1
#  - 0s - loss: 3.3337 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.4572 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.5982 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.7339 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.4319 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.3668 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.3385 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.1641 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.4496 - acc: 0.2619
# Epoch 1/1
#  - 0s - loss: 3.6890 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 3.4312 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 3.3501 - acc: 0.2619
# Epoch 1/1
#  - 0s - loss: 3.5707 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.8297 - acc: 0.1429
# Epoch 1/1
#  - 0s - loss: 3.5696 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.6454 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.8095 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.3555 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.7601 - acc: 0.1190
# Epoch 1/1
#  - 0s - loss: 3.4449 - acc: 0.2619
# Epoch 1/1
#  - 0s - loss: 3.7544 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.5491 - acc: 0.2619
# Epoch 1/1
#  - 0s - loss: 3.3423 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.6964 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.4415 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.2757 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.4667 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 3.4098 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.2133 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.4943 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 3.3330 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.7777 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.4280 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 3.2269 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.4838 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 3.2150 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.5916 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.3417 - acc: 0.1905
# Epoch 1/1
#  - 0s - loss: 3.6004 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.5374 - acc: 0.2619
# Epoch 1/1
#  - 0s - loss: 3.2570 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.3460 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.4740 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 3.2760 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 3.8100 - acc: 0.1667
# Epoch 1/1
#  - 0s - loss: 3.3295 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.2328 - acc: 0.2619
# Epoch 1/1
#  - 0s - loss: 3.5446 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.3031 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.3890 - acc: 0.2619
# Epoch 1/1
#  - 0s - loss: 3.4660 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 2.9212 - acc: 0.2619
# Epoch 1/1
#  - 0s - loss: 3.1113 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 3.3866 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.2761 - acc: 0.2619
# Epoch 1/1
#  - 0s - loss: 3.2125 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 3.2595 - acc: 0.2619
# Epoch 1/1
#  - 0s - loss: 3.1151 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 3.5308 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 3.1822 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 3.5268 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.1475 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 3.1482 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 3.4093 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.5462 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.3946 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.2133 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 3.3460 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 2.9678 - acc: 0.2619
# Epoch 1/1
#  - 0s - loss: 3.3754 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 3.6924 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 2.9794 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 3.2943 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 3.2084 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 3.4361 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.3947 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 3.2220 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 2.7576 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 3.4275 - acc: 0.2619
# Epoch 1/1
#  - 0s - loss: 3.4431 - acc: 0.2143
# Epoch 1/1
#  - 0s - loss: 3.3794 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 3.3704 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 3.2863 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 3.0709 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 3.4075 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.1926 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 3.0362 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 2.9597 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.1557 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 3.0205 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 3.0951 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 3.1120 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 3.2302 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 2.9200 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 2.6714 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.1584 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 3.4697 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.2063 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.2192 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 2.8220 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 2.9831 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 3.1067 - acc: 0.2381
# Epoch 1/1
#  - 0s - loss: 3.2962 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 3.2307 - acc: 0.2619
# Epoch 1/1
#  - 0s - loss: 3.2696 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.0954 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.9434 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.1850 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.9986 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 3.1488 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 3.3310 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.0605 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 2.9101 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.2406 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 2.8156 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.9533 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.0337 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 2.9789 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.1284 - acc: 0.2619
# Epoch 1/1
#  - 0s - loss: 3.1724 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.2580 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.0682 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 2.9604 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 2.8717 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.0763 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 3.1462 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 2.9729 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 2.6720 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 2.6763 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 3.1321 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 3.1219 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.8722 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.0775 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 2.9966 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.9639 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.8843 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 3.0072 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 2.8315 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 3.1808 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.4715 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.9067 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 2.9825 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 2.9521 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 3.0754 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 2.9047 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 3.0000 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 3.4407 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.0569 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.9431 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 2.6011 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 3.0536 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 2.8907 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 3.0094 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 2.7866 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 2.8116 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.8144 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.7951 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.8345 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.2974 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 2.9872 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.2310 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 2.8356 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 2.4767 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.9482 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 2.7007 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 3.2093 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.0863 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.7202 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.6469 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.8565 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 3.0377 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.7930 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 2.9993 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.4449 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.1965 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 3.0432 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.9626 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.8005 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 3.0229 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 3.4298 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 3.0070 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.9988 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 2.9149 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 2.7629 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 3.1008 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.1213 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 2.8106 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.5480 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 2.6372 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.7566 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.9219 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 2.8611 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 2.8465 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.7682 - acc: 0.2857
# Epoch 1/1
#  - 0s - loss: 2.9144 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 2.5910 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 3.1265 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 2.5250 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 3.1211 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 3.1374 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 2.6654 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.8376 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.0245 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.7251 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.0492 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 2.7777 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.9048 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 2.8810 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.6401 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 3.1240 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 2.9867 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 3.2781 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.1361 - acc: 0.3333
# Epoch 1/1
#  - 0s - loss: 3.0598 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.7152 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3896 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.7690 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 2.8894 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5444 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 3.0435 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 2.7938 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 3.0395 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 2.8309 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.7083 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 2.7058 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.6165 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.9717 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.7927 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 2.9358 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.3149 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5915 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.8627 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 2.5729 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.6010 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.6080 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 2.5965 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.8534 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 2.5697 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.9160 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 2.9257 - acc: 0.3095
# Epoch 1/1
#  - 0s - loss: 2.4443 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.7310 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5145 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.9106 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.7149 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 3.0709 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.8994 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 3.1305 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 3.0228 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.6827 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.7664 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 3.0348 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.4935 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5918 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.6980 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.7575 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.9729 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.7145 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.8064 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.6683 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5652 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.8903 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.6211 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.8406 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.8850 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 3.3280 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.6670 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.7404 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.7937 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.6909 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.6615 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.8770 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.7565 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.7494 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.8220 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.7298 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5244 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.3303 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2576 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.6611 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 3.1567 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.8937 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5422 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.7065 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.7421 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.7068 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.4243 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.6206 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.7864 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4872 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.6393 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.7009 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 2.9603 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3303 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.7629 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3349 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.8064 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.7459 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.6069 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.6574 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5235 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.7667 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.3003 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5824 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.6636 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3617 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.8804 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.8754 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 2.8714 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.9371 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.4023 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.6513 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.6259 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3464 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2868 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.9782 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.9477 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.4684 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.6157 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.8192 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.4981 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.7384 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4324 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.6165 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.4446 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.9346 - acc: 0.3571
# Epoch 1/1
#  - 0s - loss: 2.5502 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.7048 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.6322 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5734 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.8675 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.3936 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.6292 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.9374 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.7574 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.5502 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.5344 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3906 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4945 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3329 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4613 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5643 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.8399 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.4424 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.5470 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.7845 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.3988 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.6841 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3812 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 2.3343 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5981 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3629 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.6721 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4503 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5868 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.1394 - acc: 0.3810
# Epoch 1/1
#  - 0s - loss: 3.0034 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.4390 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.6525 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5133 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.6635 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 3.0333 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.6744 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3251 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.6100 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4232 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.4898 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1101 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5208 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.5210 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.6362 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4649 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.6292 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.6427 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3139 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.7391 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.4438 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.4212 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.8830 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.6865 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5403 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3601 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5304 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.9620 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4225 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5227 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.2054 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4297 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 3.0423 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3215 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.7013 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2686 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4803 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5823 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4432 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.8222 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3425 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3619 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1175 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.5637 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.8510 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5665 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4544 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.8639 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.2798 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.6739 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4857 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.7010 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.7010 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.2944 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5556 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.7881 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3548 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.7317 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.4768 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.2743 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.7873 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1602 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4789 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2782 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4375 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5685 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.8171 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2645 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2516 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3785 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3815 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3128 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.0763 - acc: 0.4048
# Epoch 1/1
#  - 0s - loss: 2.3456 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4818 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4742 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.8569 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3393 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2678 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3076 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2564 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2015 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.6591 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4024 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.4060 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5020 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.6365 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.5419 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5315 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.2605 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.8461 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.2585 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4249 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.4753 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.7531 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.7596 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.1439 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.0290 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.3864 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.6232 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.2774 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2427 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2413 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2270 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2891 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.5702 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5178 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.8315 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5449 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3374 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.6895 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5424 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.6026 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.7031 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3804 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.2305 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2866 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5686 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.3354 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3487 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.4166 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3024 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.1125 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1187 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.3726 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.6310 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.4053 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4984 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3510 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4231 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.2335 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3839 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1959 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1631 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.4530 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.7000 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.6410 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3768 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.6364 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 1.9344 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.3839 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.0440 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.7657 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5336 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.2750 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3682 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3922 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.3783 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3707 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.6656 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2317 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.2434 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 1.9546 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3339 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.3808 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3892 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.6964 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1748 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1177 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.3064 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4838 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.1296 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5125 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.2028 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2579 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3029 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.2113 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3979 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3551 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1297 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.0749 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.4910 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.6807 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1433 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.0824 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4056 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2058 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1265 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.2564 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.1320 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.2581 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2997 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.3829 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3986 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4405 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.0707 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3323 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5971 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5133 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.4794 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5907 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.4621 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4156 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5936 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3481 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3552 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.4737 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5022 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4443 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.1344 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.2361 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3827 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2560 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.1715 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.6718 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2616 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.1181 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.6117 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.2871 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5785 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5793 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1718 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.3997 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.6707 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3566 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.0514 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.3398 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.3195 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.1128 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.2506 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.1450 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3139 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.1129 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.4464 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.3815 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.2470 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.4151 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3329 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2489 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5662 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5354 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3819 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5438 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.2272 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.8582 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4406 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4511 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3622 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5307 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.6475 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.2131 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3526 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.2022 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2893 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2626 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.0314 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5218 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3098 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.1651 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3773 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3870 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 1.9860 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3443 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3032 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.4741 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2208 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1907 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1993 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5497 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3800 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3730 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.6613 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2890 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.8582 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 1.9311 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.0572 - acc: 0.5714
# Epoch 1/1
#  - 0s - loss: 2.4086 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.4254 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5683 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.1921 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.0041 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3914 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5082 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3673 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.4753 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4527 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5845 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3216 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.4764 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5725 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5953 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3249 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1592 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 1.9658 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4124 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.6159 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.2937 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2219 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3436 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5454 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.5443 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.4558 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1289 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.6334 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2115 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.4770 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2214 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2443 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 1.9752 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.1729 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.0870 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2780 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.0689 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.2373 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.1248 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 1.9441 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.6258 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 1.9639 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3225 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.1527 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2062 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1545 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2641 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.0948 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.2095 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 1.9967 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 1.8993 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.0340 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.5509 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4932 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.4467 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4453 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 1.9571 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.1918 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4191 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.1412 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 1.9656 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5804 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2264 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.4564 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2167 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2225 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.0353 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.0062 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.4766 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.0898 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.2507 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 1.9164 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.3986 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.0533 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4272 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3405 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 1.9272 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.0912 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.5210 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5847 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.0065 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3088 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3471 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.0512 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.3284 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4341 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.1311 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.5012 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.1220 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2755 - acc: 0.4286
# Epoch 1/1
#  - 0s - loss: 2.1816 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2982 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 1.9970 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.1998 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.0667 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 1.7201 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.1105 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1765 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3151 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 1.7555 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.2173 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3033 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.5275 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2629 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2879 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3275 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.0265 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.0974 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.6416 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.1929 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 1.9804 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.1081 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 1.8829 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.2359 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.6862 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.1914 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2644 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 1.9383 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.6054 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.2844 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.1876 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.4252 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1238 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.0705 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 1.7994 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.3333 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1991 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.2440 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.0111 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.4274 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2153 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2478 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.0125 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3529 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.1182 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3299 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.2204 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.3039 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.4377 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3422 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.0264 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.2652 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 1.9906 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2094 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.2061 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 2.0786 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 1.9866 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.0851 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.6273 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.3257 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.5420 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.2455 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.1964 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 1.9636 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.0255 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.1793 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.0220 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.0293 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 1.9883 - acc: 0.5476
# Epoch 1/1
#  - 0s - loss: 2.2773 - acc: 0.5238
# Epoch 1/1
#  - 0s - loss: 1.9723 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1613 - acc: 0.4524
# Epoch 1/1
#  - 0s - loss: 2.0973 - acc: 0.4762
# Epoch 1/1
#  - 0s - loss: 2.1905 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3930 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.6151 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.1946 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.1789 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 2.3726 - acc: 0.5238
# Epoch 1/1
# ...
#  - 0s - loss: 0.3346 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3202 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.4031 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3866 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.3356 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2969 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3102 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3317 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.4086 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3571 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.4362 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3051 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2335 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3209 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2580 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3042 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3048 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3445 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3282 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.2896 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.4920 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.2494 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2901 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3438 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3867 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2904 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3075 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3600 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3370 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.4279 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3197 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3951 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3292 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3116 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3179 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.4349 - acc: 0.8571
# Epoch 1/1
#  - 0s - loss: 0.3306 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.2963 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3859 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2680 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2647 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2890 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2134 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3452 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3034 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3602 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3276 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2495 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.4151 - acc: 0.8571
# Epoch 1/1
#  - 0s - loss: 0.2758 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2952 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3063 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3238 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2342 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2789 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3960 - acc: 0.8571
# Epoch 1/1
#  - 0s - loss: 0.3735 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.3486 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.3426 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3312 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3111 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.4066 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3384 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.4237 - acc: 0.8571
# Epoch 1/1
#  - 0s - loss: 0.2458 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3252 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2922 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3181 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3804 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.3425 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3828 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3098 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2512 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.4692 - acc: 0.8571
# Epoch 1/1
#  - 0s - loss: 0.2601 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3318 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3166 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3508 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2953 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3708 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.4566 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.3265 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2784 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3949 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2923 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3204 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.2923 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3710 - acc: 0.8333
# Epoch 1/1
#  - 0s - loss: 0.2748 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2300 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2790 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3272 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2617 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2781 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3490 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3864 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2650 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3498 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.1562 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2947 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3847 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3625 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3798 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2979 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3895 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3259 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3048 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2935 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3092 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2268 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3797 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2334 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2838 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.1621 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2885 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3039 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2568 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3904 - acc: 0.8571
# Epoch 1/1
#  - 0s - loss: 0.2204 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.4074 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2832 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2868 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2891 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2363 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3151 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3903 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3523 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3165 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.1976 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3339 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.4226 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.2472 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2921 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3059 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2854 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2554 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2707 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3362 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2833 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3143 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2630 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3162 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3697 - acc: 0.8571
# Epoch 1/1
#  - 0s - loss: 0.4249 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2983 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3042 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3541 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.2713 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2647 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3358 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2084 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2802 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2534 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3752 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3248 - acc: 0.8571
# Epoch 1/1
#  - 0s - loss: 0.2706 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2797 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2578 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2507 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2306 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3138 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2768 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2442 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2269 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2451 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2734 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2788 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2198 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3491 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2068 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2460 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2293 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2194 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3539 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2577 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2381 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2870 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2839 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2087 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2143 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2938 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2409 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2578 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3296 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2371 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3092 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2215 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3088 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3496 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2601 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2782 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2615 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2903 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3176 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2237 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3436 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3162 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2641 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.1518 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3270 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2944 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2741 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.1973 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2927 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2323 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2545 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2019 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.1630 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2585 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2886 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3612 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2122 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2519 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.1629 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.1962 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2490 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3023 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.1927 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3557 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3503 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3358 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.3948 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3221 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3399 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3266 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2329 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3242 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2259 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.1949 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2996 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2358 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2313 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2855 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3343 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.3222 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2554 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3360 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2757 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2829 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2088 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3146 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3044 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.1488 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2524 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3199 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3407 - acc: 0.8810
# Epoch 1/1
#  - 0s - loss: 0.2035 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2170 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.1747 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2879 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.1994 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1885 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2732 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2466 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2557 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2856 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2531 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2751 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2149 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2779 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2421 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2404 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3868 - acc: 0.8333
# Epoch 1/1
#  - 0s - loss: 0.2676 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2646 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3451 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.3221 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2126 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3412 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2732 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2752 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3057 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2229 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2269 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.3102 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.1783 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3063 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2770 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2565 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2880 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.1803 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.1791 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2608 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2516 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2285 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.1856 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2917 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.1885 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.1891 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2290 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2366 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2791 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2633 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3718 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2551 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2580 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2666 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2087 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2289 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2412 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2913 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2752 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2216 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2676 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3045 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.2623 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1887 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2521 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2692 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2475 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1973 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1573 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2165 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2681 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2108 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2461 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3057 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2801 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2663 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2303 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2608 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2495 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2619 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.1931 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1606 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2536 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2819 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.3069 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.1426 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2524 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.3349 - acc: 0.9048
# Epoch 1/1
#  - 0s - loss: 0.1555 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3425 - acc: 0.9286
# Epoch 1/1
#  - 0s - loss: 0.2952 - acc: 0.9524
# Epoch 1/1
#  - 0s - loss: 0.2258 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2138 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2456 - acc: 0.9762
# Epoch 1/1
#  - 0s - loss: 0.2063 - acc: 0.9762
# Expected: [78, 23] Predicted [78, 23]
# Expected: [23, 64] Predicted [23, 64]
# Expected: [64, 66] Predicted [64, 64]
# Expected: [66, 89] Predicted [66, 89]
# Expected: [89, 30] Predicted [89, 30]
# Expected: [30, 38] Predicted [30, 38]
# Expected: [38, 27] Predicted [38, 27]
# Expected: [27, 43] Predicted [27, 43]
# Expected: [43, 55] Predicted [43, 55]
# Expected: [55, 75] Predicted [55, 55]
# Expected: [75, 71] Predicted [75, 71]
# Expected: [71, 63] Predicted [71, 63]
# Expected: [63, 14] Predicted [63, 14]
# Expected: [14, 67] Predicted [14, 14]
# Expected: [67, 80] Predicted [67, 80]
# Expected: [80, 96] Predicted [80, 96]
# Expected: [96, 4] Predicted [96, 4]
# Expected: [4, 77] Predicted [4, 77]
# Expected: [77, 80] Predicted [77, 80]
# Expected: [80, 44] Predicted [80, 44]
# Expected: [44, 0] Predicted [44, 0]

# %% [markdown]
# Running the example will display log loss and accuracy on randomly generated sequences each training epoch.
#
# The chosen configuration will mean that the model will converge to 100% classification accuracy.
#
# A final randomly generated sequence is generated and expected vs predicted sequences are compared. The specific sequence generated when you run the example may differ.
#
# ## Extensions
# This section lists some possible extensions to the tutorial you may wish to explore.
#
# * **Linear Representation**. A categorical (one hot encoding) framing of the problem was used that dramatically increased the number of weights required to model this problem (100 per random integer). Explore using a linear representation (scale integers to values between 0-1) and model the problem as regression. See how this affects the skill of the system, required network size (memory units), and training time (epochs).
# * **Mask Missing Values**. When the sequence data was framed as a supervised learning problem, the rows with missing data were removed. Explore using a Masking layer or special values (e.g. -1) to allow the network to ignore or learn to ignore these values.
# * **Echo Longer Sequences**. The partial subsequence that was learned to be echoed was only 2 items long. Explore echoing longer sequences using the encoder-decoder network. Note, you will likely need larger hidden layers (more memory units) trained for longer (more epochs).
# * **Ignore State**. Care was taken to only clear state at the end of all samples of each random integer sequence and not shuffle samples within a sequence. This may not be needed. Explore and contrast model performance using a stateless LSTM with a batch size of 1 (weight updates and state reset after each sample of each sequence). I expect little to no change.
# * **Alternate Network Topologies**. Care was taken to use a TimeDistributed wrapper for the output layer to ensure that a many-to-many network was used to model the problem. Explore the sequence echo problem with a one-to-one configuration (timesteps taken as features) or a many-to-one (output taken as a vector of features) and see how this affects the required network size (memory units) and training time (epochs). I would expect it to require a larger network and take longer.
#
# ## Summary
# In this tutorial, you discovered how to develop an LSTM recurrent neural network to echo sequences and partial sequences from randomly generated lists of integers.
#
# Specifically, you learned:
#
# * How to generate random sequences of integers, represent them using a one hot encoding, and frame the problem as a supervised learning problem.
# * How to develop a sequence-to-sequence based LSTM network to echo an entire input sequence.
# * How to develop an encoder-decoder based LSTM network to echo partial input sequences with lengths that differ from the length of the input sequence.
